# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # importing the dataset

# %%
df=pd.read_csv("Car_Models.csv")

# %%
df
# Out:
#          Company          Model          Horsepower                  Torque  \
# 0        Ferrari  812 Superfast              789 hp               530 lb-ft
# 1        Ferrari     F8 Tributo              710 hp               568 lb-ft
# 2        Ferrari           Roma              611 hp               560 lb-ft
# 3        Ferrari    Portofino M              612 hp               561 lb-ft
# 4        Ferrari  SF90 Stradale              986 hp               590 lb-ft
# ..           ...            ...                 ...                     ...
# 399  Tata Motors         Safari             170 bhp                  350 Nm
# 400  Tata Motors         Altroz               90 hp                  113 Nm
# 401  Tata Motors          Tiago               70 hp                   95 Nm
# 402  Tata Motors          Tigor               70 hp                   95 Nm
# 403  Tata Motors           Thar  117 bhp @ 3500 rpm  250 Nm @ 1500-2000 rpm
#
# ...

# %%
df.columns
# Out:
# Index(['Company', 'Model', 'Horsepower', 'Torque', 'Transmission Type',
#        'Drivetrain', 'Fuel Economy', 'Number of Doors', 'Price',
#        'Model Year Range', 'Body Type', 'Engine Type', 'Number of Cylinders'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company              404 non-null    object
#  1   Model                404 non-null    object
#  2   Horsepower           404 non-null    object
#  3   Torque               404 non-null    object
#  4   Transmission Type    404 non-null    object
#  5   Drivetrain           404 non-null    object
#  6   Fuel Economy         399 non-null    object
#  7   Number of Doors      404 non-null    object
#  8   Price                398 non-null    object
#  9   Model Year Range     403 non-null    object
#  10  Body Type            403 non-null    object
#  11  Engine Type          403 non-null    object
#  12  Number of Cylinders  402 non-null    object
# dtypes: object(13)
# memory usage: 41.2+ KB

# %%
df['Number of Cylinders'].unique()
# Out:
# array(['12', '8', '3/4', '4', '3', '4 / 6', '6', '4/6/2008', '6/8', '4/6',
#        '4, 6, 2008', '6, 8', nan, '4, 6', '4, 5, 2006', '4 or 6', '0',
#        '6-8', '10', '16', '6 or 8', 'V6', '1', '3, 4'], dtype=object)

# %%
df['Number of Cylinders']=df['Number of Cylinders'].replace('[^\d.]','',regex=True)

# %%
df['Number of Cylinders']=df['Number of Cylinders'].astype(float)
# Out:
# C:\Users\sudheer akshinthala\AppData\Local\Temp\ipykernel_22032\2492074038.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Number of Cylinders']=df['Number of Cylinders'].astype(float)

# %%
df['Number of Cylinders'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 404 entries, 0 to 403
# Series name: Number of Cylinders
# Non-Null Count  Dtype
# --------------  -----
# 402 non-null    object
# dtypes: object(1)
# memory usage: 3.3+ KB

# %% [markdown]
# # Checking the null values

# %%
df.isna().sum()
# Out:
# Company                0
# Model                  0
# Horsepower             0
# Torque                 0
# Transmission Type      0
# Drivetrain             0
# Fuel Economy           5
# Number of Doors        0
# Price                  6
# Model Year Range       1
# Body Type              1
# Engine Type            1
# Number of Cylinders    2
# dtype: int64

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# Company                0
# Model                  0
# Horsepower             0
# Torque                 0
# Transmission Type      0
# Drivetrain             0
# Fuel Economy           0
# Number of Doors        0
# Price                  0
# Model Year Range       0
# Body Type              0
# Engine Type            0
# Number of Cylinders    0
# dtype: int64

# %%
df['Fuel Economy'].unique()
# Out:
# array(['13/20 mpg', '15/19 mpg', '16/24 mpg', '16/22 mpg',
#        '18 mpg (combined)', '15/20 mpg', '12/17 mpg', '15/22 mpg',
#        '16/23 mpg', '12 mpg (combined)', '13-20 km/l', '15 km/l',
#        '7-12 km/l', '16 km/l', '17 km/l', '12 km/l', '26-34 mpg',
#        '30-33 mpg', '27-40 mpg', '21-36 mpg', '16-19 mpg', '18-23 mpg',
#        '13-17 mpg', '16-21 mpg city / 24-32 mpg highway',
#        '16-20 mpg city / 22-26 mpg highway',
#        '18-21 mpg city / 24-28 mpg highway',
#        '23-26 mpg city / 31-34 mpg highway',
#        '21-22 mpg city / 28-29 mpg highway',
#        '21-23 mpg city / 26-26 mpg highway',
#        '23-25 mpg city / 28-32 mpg highway', '16-23 mpg', '15-23 mpg',
#        '22-28 mpg', '15-20 mpg', '15-22 mpg', '17-22 mpg', '28-32 mpg',
#        '23-26 mpg', '28-33 mpg', '32-35 mpg', '27-30 mpg', '20-24 mpg',
#        '13-16 mpg', '16-20 mpg', '26/33 mpg', '23/29 mpg', '21/26 mpg',
# ...

# %% [markdown]
# # converting the datatypes of the price

# %%
df['Price'].value_counts()
# Out:
# Starting at $32,990          5
# Starting at $39,990          4
# Starting at $26,990          4
# Starting at $22,990          4
# Starting at $25,295          4
#                             ..
# $20,500 - $29,400            1
# $28,025 - $43,200            1
# $24,950 - $37,350            1
# $24,100 - $34,850            1
# ₹10.55 Lakh - ₹16.78 Lakh    1
# Name: Price, Length: 322, dtype: int64

# %%
df['Price'] = df['Price'].replace('[^\d.]','',regex=True)
# Out:
# C:\Users\sudheer akshinthala\AppData\Local\Temp\ipykernel_22032\1227746280.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'] = df['Price'].replace('[^\d.]','',regex=True)

# %%
df['Price'].value_counts()
# Out:
# 32990         5
# 45900         4
# 26990         4
# 22990         4
# 24990         4
#              ..
# 2050029400    1
# 2802543200    1
# 2495037350    1
# 2410034850    1
# 10.5516.78    1
# Name: Price, Length: 312, dtype: int64

# %%
df['Price']=pd.to_numeric(df['Price'],errors = 'coerce')
# Out:
# C:\Users\sudheer akshinthala\AppData\Local\Temp\ipykernel_22032\2586046164.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price']=pd.to_numeric(df['Price'],errors = 'coerce')

# %%
df['Price'].value_counts()
# Out:
# 3.299000e+04    5
# 2.399000e+04    4
# 4.190000e+04    4
# 4.590000e+04    4
# 2.529500e+04    4
#                ..
# 3.279047e+09    1
# 2.683000e+04    1
# 2.065000e+04    1
# 2.432500e+04    1
# 2.469000e+01    1
# Name: Price, Length: 302, dtype: int64

# %%
df.head()
# Out:
#    Company          Model Horsepower     Torque  Transmission Type Drivetrain  \
# 0  Ferrari  812 Superfast     789 hp  530 lb-ft  7-speed automatic        RWD
# 1  Ferrari     F8 Tributo     710 hp  568 lb-ft  7-speed automatic        RWD
# 2  Ferrari           Roma     611 hp  560 lb-ft  8-speed automatic        RWD
# 3  Ferrari    Portofino M     612 hp  561 lb-ft  8-speed automatic        RWD
# 4  Ferrari  SF90 Stradale     986 hp  590 lb-ft  8-speed automatic        AWD
#
#         Fuel Economy Number of Doors     Price Model Year Range    Body Type  \
# 0          13/20 mpg               2  366712.0   2018 - Present        Coupe
# 1          15/19 mpg               2  276550.0   2020 - Present        Coupe
# 2          16/24 mpg               2  218750.0   2021 - Present        Coupe
# 3          16/22 mpg               2  254475.0   2021 - Present  Convertible
# 4  18 mpg (combined)               2  625000.0   2020 - Present        Coupe
#
#   Engine Type Number of Cylinders
# ...

# %% [markdown]
# plot a bargraph such that what are the car companies are present?

# %%
plt.figure(figsize=(12,4))
sns.countplot(data=df,x='Company')
plt.xticks(rotation=90)
plt.title('Companies of the cars')
# Out:
# Text(0.5, 1.0, 'Companies of the cars')

# %%
df['Number of Cylinders'].value_counts()
# Out:
# 4         161
# 6          58
# 8          51
# 0          25
# 12         22
# 3          21
# 46         18
# 68         18
# 1           7
# 34          4
# 462008      4
# 16          4
# 10          3
# 452006      1
# Name: Number of Cylinders, dtype: int64

# %%
df.head()
# Out:
#    Company          Model Horsepower     Torque  Transmission Type Drivetrain  \
# 0  Ferrari  812 Superfast     789 hp  530 lb-ft  7-speed automatic        RWD
# 1  Ferrari     F8 Tributo     710 hp  568 lb-ft  7-speed automatic        RWD
# 2  Ferrari           Roma     611 hp  560 lb-ft  8-speed automatic        RWD
# 3  Ferrari    Portofino M     612 hp  561 lb-ft  8-speed automatic        RWD
# 4  Ferrari  SF90 Stradale     986 hp  590 lb-ft  8-speed automatic        AWD
#
#         Fuel Economy Number of Doors     Price Model Year Range    Body Type  \
# 0          13/20 mpg               2  366712.0   2018 - Present        Coupe
# 1          15/19 mpg               2  276550.0   2020 - Present        Coupe
# 2          16/24 mpg               2  218750.0   2021 - Present        Coupe
# 3          16/22 mpg               2  254475.0   2021 - Present  Convertible
# 4  18 mpg (combined)               2  625000.0   2020 - Present        Coupe
#
#   Engine Type Number of Cylinders
# ...

# %%
grp2=df.groupby(['Model']).size()

# %% [raw]
# grp2.head()

# %% [markdown]
# WHat are the numner of doors present per company?

# %%
plt.figure(figsize=(12,4))
sns.barplot(data=df,x='Company',y='Number of Doors')
plt.xticks(rotation=90)
plt.title("Number of doors per company")
# Out:
# Text(0.5, 1.0, 'Number of doors per company')

# %%
df['Number of Doors']=df['Number of Doors'].replace('[^\d.]','',regex=True)
# Out:
# C:\Users\sudheer akshinthala\AppData\Local\Temp\ipykernel_22032\3860271006.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Number of Doors']=df['Number of Doors'].replace('[^\d.]','',regex=True)

# %%
df['Number of Doors']=df['Number of Doors'].astype(int)
# Out:
# C:\Users\sudheer akshinthala\AppData\Local\Temp\ipykernel_22032\2865939545.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Number of Doors']=df['Number of Doors'].astype(int)

# %%
df['Number of Doors'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 397 entries, 0 to 403
# Series name: Number of Doors
# Non-Null Count  Dtype
# --------------  -----
# 397 non-null    int32
# dtypes: int32(1)
# memory usage: 4.7 KB

# %% [markdown]
# what are the different types of body types?

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df,x="Body Type")
plt.xticks(rotation=90)
plt.title("different types of Body types")
# Out:
# Text(0.5, 1.0, 'different types of Body types')

# %% [markdown]
# what are the prices of the body types

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df,x="Body Type",y="Price")
plt.xticks(rotation=90)
plt.title("Price of the Body types")
# Out:
# C:\Users\sudheer akshinthala\anaconda3\Lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# Text(0.5, 1.0, 'Price of the Body types')

# %% [markdown]
# what is horse power per company

# %%
df[['Company','Horsepower']].head(20).value_counts().plot(kind='bar',figsize=(12,5),color=sns.color_palette())
plt.title("Horsepower per company")
# Out:
# Text(0.5, 1.0, 'Horsepower per company')

# %%
grp=df.groupby(['Company']).size()

# %%
grp.head()
# Out:
# Company
# Alfa Romeo    4
# Alpina        5
# Audi          6
# BMW           8
# Bugatti       4
# dtype: int64

# %% [markdown]
# what are the companies present in the dataset?

# %%
grp.plot(kind='bar',figsize=(12,6),color=sns.color_palette())
plt.title("Number of companies")
# Out:
# Text(0.5, 1.0, 'Number of companies')

# %% [markdown]
# display all the companies present in dataset?

# %%
grp.plot(kind='pie',figsize=(12,10),autopct="%.2f%%")
plt.title("Number of comapnies present inn dataset")
# Out:
# Text(0.5, 1.0, 'Number of comapnies present inn dataset')

# %%
df.tail()
# Out:
#          Company   Model          Horsepower                  Torque  \
# 399  Tata Motors  Safari             170 bhp                  350 Nm
# 400  Tata Motors  Altroz               90 hp                  113 Nm
# 401  Tata Motors   Tiago               70 hp                   95 Nm
# 402  Tata Motors   Tigor               70 hp                   95 Nm
# 403  Tata Motors    Thar  117 bhp @ 3500 rpm  250 Nm @ 1500-2000 rpm
#
#                      Transmission Type                         Drivetrain  \
# 399  6-speed manual, 6-speed automatic                    All-wheel drive
# 400                5-speed manual, AMT                  Front-wheel drive
# 401                     5-speed manual                  Front-wheel drive
# 402                     5-speed manual                  Front-wheel drive
# 403  5-speed manual, 6-speed automatic  Rear-wheel drive, all-wheel drive
#
#                 Fuel Economy  Number of Doors  Price Model Year Range  \
# ...

# %%
grp1=df.groupby(["Transmission Type"]).size()

# %%
grp1.head()
# Out:
# Transmission Type
# 10-speed automatic         12
# 4 speed Manual              2
# 4-motor all-wheel drive     2
# 4-speed automatic           4
# 5-speed Manual              1
# dtype: int64

# %% [markdown]
# what are the total transmission types in cars

# %%
grp1.plot(kind="bar",figsize=(12,6),color=sns.color_palette())
plt.title("Total Transmission types in cars ")
# Out:
# Text(0.5, 1.0, 'Total Transmission types in cars ')

# %% [markdown]
# what are the transmisiion types are present and plot in a histogram?

# %%
plt.figure(figsize=(12,6))
grp.plot(kind='hist')
plt.xlabel("transmission types")
plt.xticks(grp)
plt.title("Histogram for Transmission tyypes")
# Out:
# Text(0.5, 1.0, 'Histogram for Transmission tyypes')

# %%
df.tail()
# Out:
#          Company   Model          Horsepower                  Torque  \
# 399  Tata Motors  Safari             170 bhp                  350 Nm
# 400  Tata Motors  Altroz               90 hp                  113 Nm
# 401  Tata Motors   Tiago               70 hp                   95 Nm
# 402  Tata Motors   Tigor               70 hp                   95 Nm
# 403  Tata Motors    Thar  117 bhp @ 3500 rpm  250 Nm @ 1500-2000 rpm
#
#                      Transmission Type                         Drivetrain  \
# 399  6-speed manual, 6-speed automatic                    All-wheel drive
# 400                5-speed manual, AMT                  Front-wheel drive
# 401                     5-speed manual                  Front-wheel drive
# 402                     5-speed manual                  Front-wheel drive
# 403  5-speed manual, 6-speed automatic  Rear-wheel drive, all-wheel drive
#
#                 Fuel Economy  Number of Doors  Price Model Year Range  \
# ...

# %%
# Out:
# <Axes: >

# %%
df['Model Year Range'].value_counts()
# Out:
# 2023-2024         85
# 2023-Present      62
# 2019-2022         23
# 2020-present      21
# 2022-Present       8
#                   ..
# 2015-2023          1
# 2017-2023          1
# 2012-2023          1
# 2013-2021          1
# 2011 - Present     1
# Name: Model Year Range, Length: 120, dtype: int64

# %%
grp3=df.groupby(['Model Year Range']).size()

# %%
grp3=grp3.sort_values(ascending=False)

# %% [markdown]
# what are the top 20 years present in the model Year Range?

# %%
grp3.head(20).plot(kind='bar',color=sns.color_palette())
plt.title("Top 20 Model Year Range types")
# Out:
# Text(0.5, 1.0, 'Top 20 Model Year Range types')
